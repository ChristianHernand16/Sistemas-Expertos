# %% [markdown]
# # Regla de Bayes

# %% [markdown]
# Ejercicio 1

# %% [markdown]
# ➢ Una vez corregido el error del ejercicio anterior (añadir un 10% a la probabilidad de Luis), resuelva el ejercicio.
#
# ➢Se tiene dos cajas de bolígrafos. La primera contiene 23 bolígrafos azules y 17 rojos, y la segunda contiene 18 azules y
# 5 rojos.
#
# Calcular lo siguiente:

# %% [markdown]
#
# a) ¿Cuál es la probabilidad de obtener un bolígrafo azul?

# %% [markdown]
# ![oooooooooooo_opt.jpg](attachment:oooooooooooo_opt.jpg)

# %% [markdown]
# b) Si el bolígrafo que se obtuvo es rojo, ¿Cuál es la probabilidad
# de que haya sido obtenido de la caja 2?

# %% [markdown]
# ![numero111111_opt.jpg](attachment:numero111111_opt.jpg)

# %% [markdown]
# Ejercicio 2

# %% [markdown]
# En la academia de MateMovil, la probabilidad de que a un alumno seleccionado al azar le guste el helado es del 60 %, mientras que la probabilidad de que a un alumno le guste la torta es del 36 %. Además, se sabe que la probabilidad de que a un alumno le guste la torta dado que le gusta el helado es del 40 %. Calcular la probabilidad de que a un alumno le guste el helado, dado que le gusta la torta.

# %% [markdown]
# ![107814810_414071036225793_611244118607799277_n_opt.png](attachment:107814810_414071036225793_611244118607799277_n_opt.png)

# %% [markdown]
# # Calculadora

# %%
# Probabilidad Bayes
def regla_bayes(a, p, b):
# regla P(n)
    n = 1 - a
# regla P(b)
    p_b = p * a + b * n
# regla P(a|b)
    g = (p * a) / p_b
    return g
# P(a)
a = 0.6
# P(b|a)
p = 0.36
# P(b|n)
b = 0.24
# regla P(a|b)
comprobacion = regla_bayes(a, p, b)
#Realizamos la respectiva sumarizacion
print('P(a|b) = %.6f%%' % (comprobacion))
# Out:
# P(a|b) = 0.692308%

# %%
#Realizado por Christian Hernandez
